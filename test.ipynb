# %%
from config import parser
from main import main

# %%
args_str = '-s 2 graphdata/graph.data.simple.5'
FLAGS, _ = parser.parse_known_args(args=args_str.split())

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
FLAGS
# Out:
# Namespace(database_file_name='graphdata/graph.data.simple.5', directed=False, lower_bound_of_num_vertices=2, min_support=2, num_graphs=inf, plot=False, upper_bound_of_num_vertices=inf, verbose=False, where=False)

# %%
gs = main(FLAGS)
# Out:
# t # 0
# v 0 2
# v 1 2
# e 0 1 2
#
# Support: 4
# -----------------
#
# t # 1
# v 0 2
# v 1 2
# v 2 3
# e 0 1 2
# e 1 2 3
#
# Support: 2
# -----------------
#
# t # 2
# v 0 2
# v 1 2
# v 2 3
# v 3 4
# e 0 1 2
# e 1 2 3
# e 2 3 2
#
# Support: 2
# -----------------
#
# t # 3
# v 0 2
# v 1 2
# v 2 2
# e 0 1 2
# e 1 2 2
#
# Support: 2
# -----------------
#
# t # 4
# v 0 2
# v 1 2
# v 2 2
# v 3 2
# e 0 1 2
# e 1 2 2
# e 2 3 2
#
# Support: 2
# -----------------
#
# t # 5
# v 0 2
# v 1 2
# v 2 2
# v 3 2
# v 4 3
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 2 4 3
#
# Support: 2
# -----------------
#
# t # 6
# v 0 2
# v 1 2
# v 2 2
# v 3 2
# v 4 3
# v 5 4
# e 0 1 2
# e 1 2 2
# e 2 3 2
# e 2 4 3
# e 4 5 2
#
# Support: 2
# -----------------
#
# t # 7
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# e 0 1 2
# e 1 2 2
# e 1 3 3
#
# Support: 2
# -----------------
#
# t # 8
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 4
# e 0 1 2
# e 1 2 2
# e 1 3 3
# e 3 4 2
#
# Support: 2
# -----------------
#
# t # 9
# v 0 2
# v 1 2
# v 2 2
# ...

# %%
for g in gs.graphs.values():
    g.plot()
    g.display()
# Out:
# t # 0
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 2
# v 5 4
# v 6 2
# v 7 3
# v 8 3
# v 9 3
# e 0 1 2
# e 0 2 2
# e 2 3 3
# e 2 4 2
# e 3 5 2
# e 4 6 2
# e 5 7 2
# e 5 8 2
# e 5 9 2
# e 6 9 3
# t # 1
# v 0 2
# v 1 2
# v 2 6
# v 3 6
# v 4 3
# v 5 3
# v 6 3
# v 7 3
# v 8 3
# v 9 3
# e 0 1 2
# e 0 2 2
# e 1 3 2
# e 2 4 3
# e 2 5 3
# e 2 6 2
# e 3 7 3
# e 3 8 3
# e 3 9 2
# t # 2
# v 0 6
# v 1 6
# v 2 2
# v 3 2
# v 4 2
# v 5 2
# v 6 2
# v 7 2
# v 8 2
# e 0 1 2
# e 0 2 2
# e 1 3 2
# e 2 4 5
# e 2 5 5
# e 3 6 5
# e 3 7 5
# e 4 8 2
# t # 3
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 2
# v 5 4
# e 0 1 2
# e 0 2 2
# e 2 3 3
# e 2 4 2
# e 3 5 2
# t # 4
# v 0 7
# v 1 3
# v 2 5
# v 3 3
# v 4 2
# v 5 7
# v 6 2
# v 7 2
# v 8 2
# v 9 2
# e 0 1 2
# e 0 2 2
# e 0 3 3
# e 0 4 2
# e 1 5 2
# e 2 6 2
# e 2 7 2
# e 3 4 6
# e 3 5 5
# e 4 8 5
# e 4 9 5
